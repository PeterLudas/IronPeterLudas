# %% [markdown]
# ### Data marketing customer analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('Data_Marketing_Customer_Analysis_Round2.csv')
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
df.drop(columns=['Unnamed: 0','Customer'], inplace=True)

# %% [markdown]
# #### Show a plot of the total number of responses.

# %%
total_response = df['Response'].value_counts()
yes = total_response['Yes']
no = total_response['No']
sns.countplot(x=df.State, y=yes, hue=no)
#yes = df.groupby(['State'])['Response'].apply(lambda x: x.str.contains('Yes').sum())
#no = df.groupby(['State'])['Response'].apply(lambda x: x.str.contains('No').sum())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11028/3031305171.py in <module>
#       2 yes = total_response['Yes']
#       3 no = total_response['No']
# ----> 4 sns.countplot(x=df.State, y=yes, hue=no)
#       5 #yes = df.groupby(['State'])['Response'].apply(lambda x: x.str.contains('Yes').sum())
#       6 #no = df.groupby(['State'])['Response'].apply(lambda x: x.str.contains('No').sum())
#
# ~\.conda\envs\DA_Environment\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\.conda\envs\DA_Environment\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
# ...

# %%
#sns.barplot(x= df.groupby(['State']), y= responses)
#sns.barplot(x= df['State'], y= df['Response'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11028/2333075226.py in <module>
# ----> 1 sns.barplot(x= df.groupby(['State']), y= responses)
#       2 #sns.barplot(x= df['State'], y= df['Response'].
#       3
#
# ~\.conda\envs\DA_Environment\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\.conda\envs\DA_Environment\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %% [markdown]
# #### Show a plot of the response rate by the sales channel.

# %% [markdown]
# #### Show a plot of the response rate by the total claim amount.

# %% [markdown]
# #### Show a plot of the response rate by income.

# %% [markdown]
# #### Don't limit your creativity! plot any interesting findings/insights that describe some interesting facts about your data set and its variables.

# %% [markdown]
# #### Plot the Correlation Heatmap.

# %%
df.select_dtypes('number')
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
sns.heatmap(df.select_dtypes('number'), vmin=0, vmax=500)
# Out:
# <AxesSubplot:>
